# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
import sys

sys.path.append("../")
from src.eda_utils import *

# %%
DATA_DIR = "../data/ml-100k"
ratings_file = os.path.join(DATA_DIR, "u.data")

# Column names per MovieLens documentation
columns = ["user_id", "item_id", "rating", "timestamp"]
ratings = pd.read_csv(ratings_file, sep="\t", names=columns)

print(ratings.head())
print('\n')
print(ratings.describe())
print('\n')

# Let's see how many unique users and items
print("Number of unique users: ", ratings["user_id"].nunique())
print("Number of unique items: ", ratings["item_id"].nunique())
# Out:
#    user_id  item_id  rating  timestamp
# 0      196      242       3  881250949
# 1      186      302       3  891717742
# 2       22      377       1  878887116
# 3      244       51       2  880606923
# 4      166      346       1  886397596
#
#
#             user_id        item_id         rating     timestamp
# count  100000.00000  100000.000000  100000.000000  1.000000e+05
# mean      462.48475     425.530130       3.529860  8.835289e+08
# std       266.61442     330.798356       1.125674  5.343856e+06
# min         1.00000       1.000000       1.000000  8.747247e+08
# 25%       254.00000     175.000000       3.000000  8.794487e+08
# 50%       447.00000     322.000000       4.000000  8.828269e+08
# 75%       682.00000     631.000000       4.000000  8.882600e+08
# max       943.00000    1682.000000       5.000000  8.932866e+08
#
#
# Number of unique users:  943
# Number of unique items:  1682

# %%
# Basic stats of 'rating'
stats_df = get_basic_stats(ratings, "rating")
display(stats_df)

# Plot rating distribution
plot_distribution(ratings, "rating", "Rating Distribution")

# Distribution of ratings per user
plot_ratings_by_user(ratings)

# Distribution of ratings per item
plot_ratings_by_item(ratings)
# Out:
#               rating
# count  100000.000000
# mean        3.529860
# std         1.125674
# min         1.000000
# 25%         3.000000
# 50%         4.000000
# 75%         4.000000
# max         5.000000
